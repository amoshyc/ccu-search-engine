# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
df_es = pd.read_csv('../data/es_df.csv')
df_solr = pd.read_csv('../data/solr_df.csv')
df = pd.concat([df_es, df_solr], axis=1).set_index('size')

# %%
fig, ax = plt.subplots(dpi=150)
df.plot(kind='line', ax=ax, cmap=plt.cm.tab10)
ax.set_ylabel('Time(s)')
ax.set_xlabel('Number of Queries')
ax.set_title('Query Time vs Query Number')
fig.tight_layout()
fig.savefig('./vis.png')
plt.show()
